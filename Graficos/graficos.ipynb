# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# ## datos promedios

# %%
data = pd.read_csv('data_15.58.csv', sep=',', decimal='.')

data.head()
# Out:
#        id  vel_mean  tiempo_terminar  colision  react_time  quieto_count
# 0  877572  2.481086        12.000990      True    0.681709           NaN  \
# 1  536819  2.056746        13.792840      True    0.838841           NaN
# 2   10244  2.323017        54.326215     False    0.423152           NaN
# 3   81079  2.354062        53.124789     False    0.718810           NaN
# 4  370836  2.402985        52.469746     False    0.226939           NaN
#
#    cant_autos_en_drame
# 0                 25.0
# 1                 25.0
# 2                 26.0
# 3                 25.0
# 4                 25.0

# %%
data['vel_mean'] = data['vel_mean'].apply(lambda x: x*10)
data.head()
# Out:
#        id   vel_mean  tiempo_terminar  colision  react_time  quieto_count
# 0  877572  24.810863        12.000990      True    0.681709           NaN  \
# 1  536819  20.567464        13.792840      True    0.838841           NaN
# 2   10244  23.230168        54.326215     False    0.423152           NaN
# 3   81079  23.540624        53.124789     False    0.718810           NaN
# 4  370836  24.029854        52.469746     False    0.226939           NaN
#
#    cant_autos_en_drame
# 0                 25.0
# 1                 25.0
# 2                 26.0
# 3                 25.0
# 4                 25.0

# %%
#hacer hsitograma de las velocidades promedio de los autos 

plt.plot(data['vel_mean'], color='red', linestyle='dashed', linewidth=1)
plt.xlabel('Cantidad de autos')
plt.ylabel('Velocidad promedio (m/s)')
plt.title('Velocidad promedio de los autos a lo largo del tiempo')
plt.grid(True)  # Add grid lines
plt.show()

# %%
# Assuming you have already loaded your data into a DataFrame named 'data'
velocities = data['vel_mean']

# Create a histogram with KDE (Kernel Density Estimation) plot
sns.histplot(velocities, bins=20, kde=True, color='red', label='vel_mean')

plt.xlabel('Velocidad promedio (m/s)')
plt.ylabel('Frecuencia')
plt.title('Histograma de velocidades promedio con el mejor ajuste')
plt.legend()
plt.show()

# %%
velocities = data['react_time']

# Create a histogram with KDE (Kernel Density Estimation) plot
sns.histplot(velocities, bins=20, kde=False, color='lightblue')

plt.xlabel('reaction time (segs)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Reaction time per driver')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Assuming you have already loaded your data into a DataFrame named 'data'
velocities = data['vel_mean']
cant_autos = data['cant_autos_en_drame']

plt.figure(figsize=(10, 6))
plt.bar(cant_autos, velocities, width=3)

plt.xlabel('Cantidad de Autos al Terminar')
plt.ylabel('Velocidad Promedio (m/s)')
plt.title('Histograma de Velocidades Promedio por Cantidad de Autos')

plt.xticks(cant_autos)  # Para mostrar todas las cantidades en el eje x
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()

# %% [markdown]
# ## velocidades puntuales por auto

# %%
velocidades = pd.read_csv('velocidades.csv', sep=',', decimal='.')
velocidades.head()
# Out:
#           0         1         2         3         4         5         6
# 0  2.806008  2.803167  2.807114  2.805670  2.806342  2.805995  2.806096  \
# 1  1.176189  1.846363  2.686363  2.686363  2.686363  2.686363  2.686363
# 2  0.670448  1.805556  2.895759  3.435383  3.691804  4.019758  4.019758
# 3  1.183972  1.287780  1.405295  2.068021  1.593371  2.136094  2.237399
# 4  2.731909  2.731623  2.726002  2.722806  2.711441  2.680176  2.637945
#
#           7         8         9  ...       341       342       343       344
# 0  2.806053  2.806054  2.806026  ...  2.806054  2.806054  2.806054  2.806054  \
# 1  2.686363  2.686363  2.686363  ...  1.135340  1.793585  1.017464  1.206390
# 2  4.019758  4.019758  4.019758  ...  1.010350  1.430232  1.415171  1.678562
# 3  1.842502  2.231980  1.298145  ...  1.201025  1.887264  2.439810  1.371751
# 4  2.580265  2.508887  2.424105  ...  2.756365  1.926697  1.546658  1.913879
#
#         345       346       347       348       349       350
# ...

# %%
velocidades = pd.read_csv('velocidades.csv', sep=',', decimal='.')
#plotear cada fila como una linea particular dodne x es el tiempo en segs y y es la velocidad en m/s^-10
#hacer un plot donde cada fila sea una linea particular donde x es el tiempo en segs y y es la velocidad en m/s^-10
#todo debe estar en un mismo plot 
def generar_color_aleatorio():
    r = random.random()
    g = random.random()
    b = random.random()
    return (r, g, b)

num_colores = 10  # Número de colores aleatorios que deseas generar
colores = [generar_color_aleatorio() for _ in range(num_colores)]

for i in range(0, velocidades.shape[0]):
    color_i = generar_color_aleatorio()
    plt.plot(velocidades.iloc[i,:], color = color_i, linestyle='dashed', linewidth=1)
    print(i, color_i)
plt.xlabel('Tiempo (segs)')
plt.ylabel('Velocidad (m/s)')
plt.title('Velocidad de los autos a lo largo del tiempo')
plt.grid(True)  # Add grid lines
plt.show()
# Out:
# 0 (0.021077828461383508, 0.975280518902769, 0.933746664650547)
# 1 (0.238002163119303, 0.8627119730257483, 0.5308768554968696)
# 2 (0.18665981724602865, 0.4496716988073085, 0.581010352047521)
# 3 (0.1146374190033006, 0.8208668844454439, 0.7221344514649101)
# 4 (0.6938941357492824, 0.2507031623849577, 0.6787399684651844)
# 5 (0.2366564230874838, 0.46373805438264115, 0.5695939887741813)
# 6 (0.1591710260652296, 0.9595841289258076, 0.9843612528102472)
# 7 (0.07930261588713039, 0.3366802663861198, 0.42629758083716895)
# 8 (0.41713712388447577, 0.18115688646207329, 0.39222248680307403)
# 9 (0.19383890523678504, 0.7224684430949352, 0.38588786081383486)
# 10 (0.9278691161271374, 0.6362495493188304, 0.04080275957942259)
# 11 (0.93377390552315, 0.8736744503141443, 0.1757193013894679)
# 12 (0.6131485973638842, 0.016157046901958627, 0.3211322891900398)
# 13 (0.36023636617744337, 0.9962557201895543, 0.9155305177116123)
# 14 (0.30012825655093944, 0.0405879040773055, 0.20108064270222814)
# ...

# %%
velocidades = pd.read_csv('velocidades_sin_collision.csv', sep=',', decimal='.')
#plotear cada fila como una linea particular dodne x es el tiempo en segs y y es la velocidad en m/s^-10
#hacer un plot donde cada fila sea una linea particular donde x es el tiempo en segs y y es la velocidad en m/s^-10
#todo debe estar en un mismo plot 
def generar_color_aleatorio():
    r = random.random()
    g = random.random()
    b = random.random()
    return (r, g, b)

num_colores = 20  # Un color aleatorio por cada fila en el DataFrame
colores = [generar_color_aleatorio() for _ in range(num_colores)]

# Crear un gráfico para trazar las velocidades
plt.figure(figsize=(10, 6))  # Ajustar el tamaño del gráfico

for i in range(num_colores):
    tiempo = range(len(velocidades.iloc[i, :]))  # Tiempo en segundos (0, 1, 2, ...)
    velocidad = velocidades.iloc[i, :]  # Velocidades de una fila específica

    # Utilizar el color aleatorio y agregar etiquetas para la leyenda
    plt.plot(tiempo, velocidad, color=colores[i], label=f'Auto {i+1}')

plt.xlabel('Tiempo')
plt.ylabel('Velocidad (m/s^-10)')
plt.ylim(-1, 10)  # Limitar el eje y entre 0 y 10
plt.title('Velocidad de los autos a lo largo del tiempo')
plt.grid(True)  # Agregar líneas de cuadrícula
plt.legend()  # Mostrar la leyenda
plt.show()
