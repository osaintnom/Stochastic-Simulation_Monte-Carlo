# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      -------------------------------------- 293.3/293.3 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=0.25->seaborn) (2022.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\fedep\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\fedep\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data_9.11.csv', sep=',', decimal='.')

data.head()
# Out:
#        id  vel_mean  tiempo_terminar  colision  react_time  quieto_count
# 0  575633  8.725814        37.918940     False    0.288162             0
# 1  786718  7.886673        42.228787     False    0.133618             0
# 2  842247  7.701857        43.119722     False    0.136687             0
# 3   32919  8.003010        41.900853     False    0.262555             0
# 4  585493  8.019368        42.103208     False    0.156411             0

# %%
data['vel_mean'] = data['vel_mean'].apply(lambda x: x*10)
data.head()
# Out:
#        id   vel_mean  tiempo_terminar  colision  react_time  quieto_count
# 0  575633  87.258141        37.918940     False    0.288162             0
# 1  786718  78.866727        42.228787     False    0.133618             0
# 2  842247  77.018567        43.119722     False    0.136687             0
# 3   32919  80.030096        41.900853     False    0.262555             0
# 4  585493  80.193679        42.103208     False    0.156411             0

# %%
#hacer hsitograma de las velocidades promedio de los autos 

plt.plot(data['vel_mean'], color='red', linestyle='dashed', linewidth=1)
plt.xlabel('Cantidad de autos')
plt.ylabel('Velocidad promedio (m/s)')
plt.title('Velocidad promedio de los autos a lo largo del tiempo')
plt.grid(True)  # Add grid lines
plt.show()

# %%
# Assuming you have already loaded your data into a DataFrame named 'data'
velocities = data['vel_mean']

# Create a histogram with KDE (Kernel Density Estimation) plot
sns.histplot(velocities, bins=20, kde=True, color='red', label='vel_mean')

plt.xlabel('Velocidad promedio (km/h)')
plt.ylabel('Frecuencia')
plt.title('Histograma de velocidades promedio con el mejor ajuste')
plt.legend()
plt.show()

# %%
velocities = data['react_time']

# Create a histogram with KDE (Kernel Density Estimation) plot
sns.histplot(velocities, bins=20, kde=False, color='lightblue')

plt.xlabel('reaction time (segs)')
plt.ylabel('Frecuencia')
plt.title('Histograma de Reaction time per driver')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
